# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, we summarize some of the most popular Data Science tools, languages, and libraries.

# %% [markdown]
# ## Data Science Languages
# Some of the popular languages used by data scientists include:
#
# - Python
# - R
# - SQL
# - Julia

# %% [markdown]
# ## Data Science Libraries
# Commonly used Data Science libraries include:
#
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Tool                | Category               |
# |---------------------|------------------------|
# | Jupyter Notebook    | Notebook Environment   |
# | RStudio             | IDE for R              |
# | Apache Spark        | Big Data Processing    |

# %% [markdown]
# ### Examples of arithmetic expressions
# Below are some examples of arithmetic expressions used in Python:
#
# - `2 + 3`
# - `4 * 5`
# - `10 / 2`
# - `5 - 1`

# %% [markdown]
# # Multiplying and adding numbers
# (3 * 4) + 5

# %% [markdown]
# # Converting minutes to hours
# minutes = 200
# hours = minutes / 60
# hours

# %% [markdown]
# ## Objectives
# In this notebook, you will learn to:
#
# - Identify data science languages
# - List common data science libraries
# - Create tables using Markdown
# - Perform arithmetic operations in Python
# - Convert units using Python code

# %% [markdown]
# ## Author
# Vanessa Queiroz
